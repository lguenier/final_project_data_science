# %%
import pandas as pd

# %%
sun_data = pd.read_csv('./data/UN_data.csv')

# %%
sun_data.shape
# Out:
# (5, 36)

# %%
sun_data.head()
# Out:
#   Country or Territory            Station Name  WMO Station Number  \
# 0           LUXEMBOURG              LUXEMBOURG              6590.0
# 1           LUXEMBOURG              LUXEMBOURG              6590.0
# 2            SINGAPORE        SINGAPORE/CHANGI             48698.0
# 3        footnoteSeqID                Footnote                 NaN
# 4                    1  code for missing value                 NaN
#
#    National Station Id Number     Period  Element-Statistic Qualifier Code  \
# 0                         NaN  1961-1990                               NaN
# 1                         NaN  1961-1990                               NaN
# 2                         NaN  1961-1990                               NaN
# 3                         NaN        NaN                               NaN
# 4                         NaN        NaN                               NaN
#
#   Statistic Description Unit    Jan  Jan Footnotes  ...    Oct  Oct Footnotes  \
# 0   Percent of Possible    *   16.7            NaN  ...   33.0            NaN
# 1  Mean Number of Hours    *   43.9            NaN  ...  108.9            NaN
# 2  Mean Number of Hours    *  172.4            NaN  ...  155.2            NaN
# 3                   NaN  NaN    NaN            NaN  ...    NaN            NaN
# 4                   NaN  NaN    NaN            NaN  ...    NaN            NaN
#
#      Nov  Nov Footnotes    Dec  Dec Footnotes  Annual  Annual Footnotes  \
# 0   20.7            NaN   17.2            NaN    35.9               NaN
# 1   55.5            NaN   42.8            NaN  1630.2               NaN
# 2  129.6            NaN  133.5            NaN  2022.4               NaN
# 3    NaN            NaN    NaN            NaN     NaN               NaN
# 4    NaN            NaN    NaN            NaN     NaN               NaN
#
#    Annual NCDC Computed Value  Annual NCDC Computed Value Footnotes
# 0                     -9999.9                                   1.0
# 1                      1630.2                                   NaN
# 2                      2022.4                                   NaN
# 3                         NaN                                   NaN
# 4                         NaN                                   NaN
#
# [5 rows x 36 columns]

# %%
is_mean_nbr_hours = sun_data['Statistic Description'] == 'Mean Number of Hours'
sun_data = sun_data[is_mean_nbr_hours].copy()

# %%
clean_data = data.dropna()
